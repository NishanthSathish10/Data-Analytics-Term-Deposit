# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df=pd.read_csv('/content/bank-additional.csv',sep=";")

# %%
sns.catplot(x="age", y="y", data=df);

# %%
sns.scatterplot(y="duration", x="y",data=df)

# %%
sns.catplot(y="duration",x="y",data=df)

# %%
sns.catplot(y="campaign",x="y",data=df)

# %%
sns.catplot(y="pdays",x="y",data=df[df.pdays != 999])

# %%
sns.catplot(y="previous",x="y",data=df)

# %%
sns.scatterplot(y="previous",x="y",data=df)

# %%
sns.countplot(x ='poutcome',hue ='y', data = df)

# %%
sns.countplot(x ='poutcome',hue ='y', data = df[df.poutcome != "nonexistent"])

# %%
sns.catplot(y="emp.var.rate",x="y",data=df)

# %%
sns.catplot(y="cons.price.idx",x="y",data=df)

# %%
sns.catplot(y="euribor3m",x="y",data=df)

# %%
sns.catplot(y="nr.employed",x="y",data=df)

# %%
corr=df.corr()

# %%
corr
# Out:
#                      age  duration  ...  euribor3m  nr.employed
# age             1.000000  0.041299  ...  -0.015033    -0.041936
# duration        0.041299  1.000000  ...  -0.032329    -0.044218
# campaign       -0.014169 -0.085348  ...   0.159435     0.161037
# pdays          -0.043425 -0.046998  ...   0.301478     0.381983
# previous        0.050931  0.025724  ...  -0.458851    -0.514853
# emp.var.rate   -0.019192 -0.028848  ...   0.970308     0.897173
# cons.price.idx -0.000482  0.016672  ...   0.657159     0.472560
# cons.conf.idx   0.098135 -0.034745  ...   0.276595     0.107054
# euribor3m      -0.015033 -0.032329  ...   1.000000     0.942589
# nr.employed    -0.041936 -0.044218  ...   0.942589     1.000000
#
# [10 rows x 10 columns]

# %%
fig, ax = plt.subplots(figsize = (16,8))
sns.heatmap(corr,ax=ax,cmap="Blues")

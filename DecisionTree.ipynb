# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
import random
# %matplotlib inline

# %%
df=pd.read_csv('/content/drive/MyDrive/DA-Project/bank-additional-full.csv',sep=";")

# %%
for i in df:
  print(i,df[i].dtype)
# Out:
# age int64
# job object
# marital object
# education object
# default object
# housing object
# loan object
# contact object
# month object
# day_of_week object
# duration int64
# campaign int64
# pdays int64
# previous int64
# poutcome object
# emp.var.rate float64
# cons.price.idx float64
# cons.conf.idx float64
# euribor3m float64
# nr.employed float64
# y object

# %%
del df['duration']

# %%
#Checking for duplicates
duplicate_rows_df = df.duplicated()
print(duplicate_rows_df.sum())
# Out:
# 1784

# %%
df.drop_duplicates(inplace=True)

# %%
duplicate_rows_df = df.duplicated()
print(duplicate_rows_df.sum())
# Out:
# 0

# %%
count = 0
for i in df['y']:
  if i == "no":
    count = count+1
print(count)
# Out:
# 34806

# %%
df
# Out:
#        age          job  marital  ... euribor3m nr.employed    y
# 0       56    housemaid  married  ...     4.857      5191.0   no
# 1       57     services  married  ...     4.857      5191.0   no
# 2       37     services  married  ...     4.857      5191.0   no
# 3       40       admin.  married  ...     4.857      5191.0   no
# 4       56     services  married  ...     4.857      5191.0   no
# ...    ...          ...      ...  ...       ...         ...  ...
# 41183   73      retired  married  ...     1.028      4963.6  yes
# 41184   46  blue-collar  married  ...     1.028      4963.6   no
# 41185   56      retired  married  ...     1.028      4963.6   no
# 41186   44   technician  married  ...     1.028      4963.6  yes
# 41187   74      retired  married  ...     1.028      4963.6   no
#
# [39404 rows x 20 columns]

# %%
random.random()
# Out:
# 0.19257679608270795

# %%
data1 = df.loc[(df["y"] == "yes")]
data1.shape
# Out:
# (4598, 20)

# %%
data2 = df.loc[(df["y"] == "no")]
data2.shape
# Out:
# (34806, 20)

# %%
data2
# Out:
#        age          job  marital  ... euribor3m nr.employed   y
# 0       56    housemaid  married  ...     4.857      5191.0  no
# 1       57     services  married  ...     4.857      5191.0  no
# 2       37     services  married  ...     4.857      5191.0  no
# 3       40       admin.  married  ...     4.857      5191.0  no
# 4       56     services  married  ...     4.857      5191.0  no
# ...    ...          ...      ...  ...       ...         ...  ..
# 41180   36       admin.  married  ...     1.028      4963.6  no
# 41182   29   unemployed   single  ...     1.028      4963.6  no
# 41184   46  blue-collar  married  ...     1.028      4963.6  no
# 41185   56      retired  married  ...     1.028      4963.6  no
# 41187   74      retired  married  ...     1.028      4963.6  no
#
# [34806 rows x 20 columns]

# %%
data1
# Out:
#        age           job   marital  ... euribor3m nr.employed    y
# 75      41   blue-collar  divorced  ...     4.857      5191.0  yes
# 83      49  entrepreneur   married  ...     4.857      5191.0  yes
# 88      49    technician   married  ...     4.857      5191.0  yes
# 129     41    technician   married  ...     4.857      5191.0  yes
# 139     45   blue-collar   married  ...     4.857      5191.0  yes
# ...    ...           ...       ...  ...       ...         ...  ...
# 41174   62       retired   married  ...     1.031      4963.6  yes
# 41178   62       retired   married  ...     1.031      4963.6  yes
# 41181   37        admin.   married  ...     1.028      4963.6  yes
# 41183   73       retired   married  ...     1.028      4963.6  yes
# 41186   44    technician   married  ...     1.028      4963.6  yes
#
# [4598 rows x 20 columns]

# %%
np.random.seed(10)
#deleting random samples with y = 'no'
remove_n = 24806
drop_indices = np.random.choice(data2.index, remove_n, replace=False)
data2_subset = data2.drop(drop_indices)

# %%
data2_subset
# Out:
#        age          job  marital  ... euribor3m nr.employed   y
# 1       57     services  married  ...     4.857      5191.0  no
# 2       37     services  married  ...     4.857      5191.0  no
# 4       56     services  married  ...     4.857      5191.0  no
# 6       59       admin.  married  ...     4.857      5191.0  no
# 12      29  blue-collar   single  ...     4.857      5191.0  no
# ...    ...          ...      ...  ...       ...         ...  ..
# 41149   30       admin.   single  ...     1.039      4963.6  no
# 41152   26   management   single  ...     1.039      4963.6  no
# 41154   41   technician  married  ...     1.039      4963.6  no
# 41182   29   unemployed   single  ...     1.028      4963.6  no
# 41184   46  blue-collar  married  ...     1.028      4963.6  no
#
# [10000 rows x 20 columns]

# %%
data2 = data2_subset

# %%
data = pd.concat([data1,data2])

# %%
del data['pdays']

# %%
data.hist(figsize=(8,8), xrot=45)
plt.show()

# %%
#Converting table to One Hot Encoded form
cat=data.select_dtypes(include="object")

# %%
enc_cat = pd.get_dummies(cat)

# %%
enc_cat
# Out:
#        job_admin.  job_blue-collar  ...  y_no  y_yes
# 75              0                1  ...     0      1
# 83              0                0  ...     0      1
# 88              0                0  ...     0      1
# 129             0                0  ...     0      1
# 139             0                1  ...     0      1
# ...           ...              ...  ...   ...    ...
# 41149           1                0  ...     1      0
# 41152           0                0  ...     1      0
# 41154           0                0  ...     1      0
# 41182           0                0  ...     1      0
# 41184           0                1  ...     1      0
#
# [14598 rows x 54 columns]

# %%
for i in cat:
  del data[i]

# %%
data = pd.concat([data,enc_cat],axis = 1)

# %%
data
# Out:
#        age  campaign  previous  ...  poutcome_success  y_no  y_yes
# 75      41         1         0  ...                 0     0      1
# 83      49         1         0  ...                 0     0      1
# 88      49         1         0  ...                 0     0      1
# 129     41         1         0  ...                 0     0      1
# 139     45         1         0  ...                 0     0      1
# ...    ...       ...       ...  ...               ...   ...    ...
# 41149   30         2         0  ...                 0     1      0
# 41152   26         5         0  ...                 0     1      0
# 41154   41         2         0  ...                 0     1      0
# 41182   29         1         1  ...                 1     1      0
# 41184   46         1         0  ...                 0     1      0
#
# [14598 rows x 62 columns]

# %%
del data["y_no"]

# %%
data.rename(columns={'y_yes': 'y'}, inplace=True)

# %%
data
# Out:
#        age  campaign  previous  ...  poutcome_nonexistent  poutcome_success  y
# 75      41         1         0  ...                     1                 0  1
# 83      49         1         0  ...                     1                 0  1
# 88      49         1         0  ...                     1                 0  1
# 129     41         1         0  ...                     1                 0  1
# 139     45         1         0  ...                     1                 0  1
# ...    ...       ...       ...  ...                   ...               ... ..
# 41149   30         2         0  ...                     1                 0  0
# 41152   26         5         0  ...                     1                 0  0
# 41154   41         2         0  ...                     1                 0  0
# 41182   29         1         1  ...                     0                 1  0
# 41184   46         1         0  ...                     1                 0  0
#
# ...

# %%
#checking for null values
data.isnull().sum()
# Out:
# age                     0
# campaign                0
# previous                0
# emp.var.rate            0
# cons.price.idx          0
#                        ..
# day_of_week_wed         0
# poutcome_failure        0
# poutcome_nonexistent    0
# poutcome_success        0
# y                       0
# Length: 61, dtype: int64

# %%
Y = data['y']

# %%
X = data.drop(['y'],axis = 1)

# %%
from sklearn.model_selection import train_test_split
#Splitting the Dataset into training and testing dataset

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X,Y, random_state = 101, stratify = Y, test_size = 0.25)

# %%
y_train.value_counts(normalize = True)
# Out:
# 0    0.685057
# 1    0.314943
# Name: y, dtype: float64

# %%
y_valid.value_counts(normalize = True)
# Out:
# 0    0.684932
# 1    0.315068
# Name: y, dtype: float64

# %%
X_train.shape , y_train.shape
# Out:
# ((10948, 60), (10948,))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier(random_state=10)

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=10)

# %%
dt_model.score(X_train,y_train)
# Out:
# 0.9967117281695287

# %%
dt_model.score(X_valid, y_valid)
# Out:
# 0.6887671232876712

# %%
dt_model.predict(X_valid)
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=uint8)

# %%
dt_model.predict_proba(X_valid)
# Out:
# array([[1. , 0. ],
#        [1. , 0. ],
#        [0.5, 0.5],
#        ...,
#        [1. , 0. ],
#        [0. , 1. ],
#        [1. , 0. ]])

# %%
y_pred = dt_model.predict_proba(X_valid)[:,1]

# %%
new_y = []
for i in range(len(y_pred)):
  if y_pred[i] < 0.4:
    new_y.append(0)
  else:
    new_y.append(1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_valid, new_y)
# Out:
# 0.689041095890411

# %%
train_accuracy = []
validation_accuracy = []
for depth in range(1,10):
  dt_model = DecisionTreeClassifier(max_depth=depth, random_state = 10)
  dt_model.fit(X_train,y_train)
  train_accuracy.append(dt_model.score(X_train,y_train))
  validation_accuracy.append(dt_model.score(X_valid,y_valid))

# %%
frame = pd.DataFrame({'max_depth':range(1,10),'train_acc':train_accuracy, 'valid_acc':validation_accuracy})
frame.head()
# Out:
#    max_depth  train_acc  valid_acc
# 0          1   0.783979   0.775342
# 1          2   0.783979   0.775342
# 2          3   0.792930   0.782466
# 3          4   0.800420   0.792603
# 4          5   0.803343   0.795890

# %%
#Checking for optimal depth of Decision Tree by comparing accuracy for different depths
plt.figure(figsize = (12,6))
plt.plot(frame['max_depth'],frame['train_acc'],marker = '*')
plt.plot(frame['max_depth'],frame['valid_acc'],marker = 'o')
plt.xlabel('Depth of tree')
plt.ylabel('Performance')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
dt_model = DecisionTreeClassifier(max_depth=7, max_leaf_nodes=25, random_state=10)
dt_model.fit(X_train,y_train)
dt_model.score(X_train,y_train)
# Out:
# 0.8057179393496529

# %%
dt_model.score(X_valid,y_valid)
# Out:
# 0.7975342465753424

# %%
from sklearn import tree

# %%
# !pip install graphviz

# %%
decision_tree = tree.export_graphviz(dt_model,out_file='tree.dot',feature_names=X_train.columns, max_depth=7, filled = True)

# %%
# !dot -Tpng tree.dot -o tree.png

# %%
#Plotting the decision tree
image = plt.imread('tree.png')
plt.figure(figsize = (20,20))
plt.imshow(image)

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
#Checking model performance
y_pred = dt_model.predict_proba(X_valid)[:,1]
new_y = []
for i in range(len(y_pred)):
  if y_pred[i] < 0.4:
    new_y.append(0)
  else:
    new_y.append(1)
acc = accuracy_score(y_valid, new_y)
pred = dt_model.predict(X_valid)
precision = precision_score(y_valid, pred)
recall = recall_score(y_valid, pred)
f1 = 2*(precision*recall)/(precision+recall)

# %%
acc
# Out:
# 0.7975342465753424

# %%
precision
# Out:
# 0.7397899649941657

# %%
recall
# Out:
# 0.551304347826087

# %%
f1
# Out:
# 0.6317887394120579
